# %% [markdown]
# ### Import de libs / frameworks

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline

plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ### Gráfico de Linha

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, 'b-', linewidth=2, label='sen(x)')

plt.title('Função Seno', fontsize=16)
plt.xlabel('x', fontsize=14)
plt.ylabel('sen(x)', fontsize=14)
plt.grid(True)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### O gráfico de linha é usado para mostrar tendências ao longo do tempo. A dimensão está sempre no eixo x(horizontal) e as medidas no eixo y (vertical). Se o seu conjunto de dados deve ter pelo menos dois pontos de dados para desenhar uma linha. Um conjunto de dados com valor único é exibido como um ponto.

# %% [markdown]
# ### Múltiplas linhas

# %%
x = np.linspace(0, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.sin(x) * np.cos(x)

plt.figure(figsize=(12, 6))

plt.plot(x, y1, 'r-', linewidth=2, label='sen(x)')
plt.plot(x, y2, 'g-', linewidth=2, label='cos(x)')
plt.plot(x, y3, 'b--', linewidth=2, label='sen(x)·cos(x)')

plt.title('Funções Trigonométricas', fontsize=16)
plt.xlabel('x', fontsize=14)
plt.ylabel('y', fontsize=14)
plt.grid(True)
plt.legend(fontsize=12)
plt.axhline(y=0, color='k', linestyle='-', alpha=0.3)
plt.axvline(x=np.pi, color='k', linestyle='--', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Esse tipo de gráfico serve para comparar diversas séries de dados ao longo do tempo. Ao utilizar evoluções de diferentes ações no período.

# %% [markdown]
# ### Gráfico de dispersão ou Scatter

# %%
np.random.seed(42)
x = np.random.rand(50)
y = x + 0.3*np.random.randn(50)
cores = np.random.rand(50)
tamanhos = 1000 * np.random.rand(50)

plt.figure(figsize=(10, 6))

scatter = plt.scatter(x, y, c=cores, s=tamanhos, alpha=0.6, cmap='viridis')

plt.colorbar(scatter, label='Valor de Cor')
plt.title('Gráfico de Dispersão com Cores e Tamanhos Variáveis', fontsize=16)
plt.xlabel('Eixo X', fontsize=14)
plt.ylabel('Eixo Y', fontsize=14)
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### O gráfico de dispersão são utilizados para determinar a força de um relacionamento entre duas variaveis numéricas. O eixo-x representa a variável independente e o eixo-y  representa a variável dependente.

# %% [markdown]
# ### Histograma

# %%
np.random.seed(42)
dados = np.random.normal(0, 1, 1000)
plt.figure(figsize=(10, 6))

plt.hist(dados, bins=30, alpha=0.7, color='skyblue', edgecolor='black')
plt.title('Histograma de uma Distribuição Normal', fontsize=16)
plt.xlabel('Valor', fontsize=14)
plt.ylabel('Frequência', fontsize=14)
plt.grid(True, alpha=0.3)

plt.axvline(dados.mean(), color='r', linestyle='dashed', linewidth=2,
label=f'Média: {dados.mean():.2f}')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### O histograma, também conhecido como diagrama de dispersão de frequencias, é uma representação gráfica de dados que são divididos em classes. Essa representação gráfica é geita com o objetivo de conferir como um processo se comporta em relação as suas especificidades.

# %% [markdown]
# ### Boxplot

# %%
np.random.seed(42)
dados1 = np.random.normal(0, 1, 100)
dados2 = np.random.normal(2, 1.5, 100)
dados3 = np.random.normal(-1, 2, 100)

plt.figure(figsize=(10, 6))

plt.boxplot([dados1, dados2, dados3], labels=['Grupo A', 'Grupo B', 'Grupo C'],
patch_artist=True, boxprops=dict(facecolor='lightblue'))

plt.title('Boxplot Comparativo entre Grupos', fontsize=16)
plt.xlabel('Grupos', fontsize=14)
plt.ylabel('Valores', fontsize=14)
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_17690/309266675.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([dados1, dados2, dados3], labels=['Grupo A', 'Grupo B', 'Grupo C'],

# %% [markdown]
# ### O boxplot é uma visualização estatística que resume a distribuição de uma variável numérica por meio de cinco principais medidas: minimo, primeiro quartil, mediana, terceiro quartil, maximo.

# %% [markdown]
# ### Gráfico de Violino

# %%
dados = [dados1, dados2, dados3]

plt.figure(figsize=(10, 6))

parts = plt.violinplot(dados, showmeans=True, showmedians=True)

for pc, color in zip(parts['bodies'], ['skyblue', 'lightgreen', 'salmon']):
   pc.set_facecolor(color)
   pc.set_alpha(0.7)

plt.title('Gráfico de Violino Comparativo', fontsize=16)
plt.xlabel('Grupos', fontsize=14)
plt.ylabel('Valores', fontsize=14)
plt.xticks([1, 2, 3], ['Grupo A', 'Grupo B', 'Grupo C'])
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### O gráfico de violino é uma combinação entre o boxplot e a curva de densidade, usado para visualizar a distribuição de uma variável numérica. Ele mostra a mediana, os quartis e os outliers como no boxplot, mas adiciona uma curva espelhada que representa a densidade dos dados ao longo do eixo Y quanto mais larga a parte do violino, maior a concentração de dados ali.

# %% [markdown]
# ### Gráfico de Barras Simples

# %%
categorias = ['A', 'B', 'C', 'D', 'E']
valores = [25, 40, 30, 55, 15]

plt.figure(figsize=(10, 6))

barras = plt.bar(categorias, valores, color='skyblue', edgecolor='navy')

for barra in barras:
   altura = barra.get_height()
   plt.text(barra.get_x() + barra.get_width()/2., altura + 1,
   f'{altura}', ha='center', va='bottom', fontsize=12)

plt.title('Gráfico de Barras por Categoria', fontsize=16)
plt.xlabel('Categorias', fontsize=14)
plt.ylabel('Valores', fontsize=14)
plt.ylim(0, max(valores) * 1.2)
plt.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### O gráfico de barras simples é utilizado para representar e comparar valores de variáveis categóricas, ou seja, aquelas que representam grupos ou rótulos (como produtos, países, tipos de cliente etc.)

# %% [markdown]
# ### Gráfico de Barras Agrupadas

# %%
categorias = ['Grupo 1', 'Grupo 2', 'Grupo 3', 'Grupo 4']
homens = [22, 30, 35, 25]
mulheres = [25, 32, 30, 28]

largura = 0.35
x = np.arange(len(categorias))

plt.figure(figsize=(12, 6))

plt.bar(x - largura/2, homens, largura, label='Homens', color='skyblue',
edgecolor='navy')
plt.bar(x + largura/2, mulheres, largura, label='Mulheres',
color='lightpink', edgecolor='red')

plt.title('Comparação por Gênero entre Grupos', fontsize=16)
plt.xlabel('Grupos', fontsize=14)
plt.ylabel('Valores', fontsize=14)
plt.xticks(x, categorias)
plt.legend()
plt.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### O gráfico de barras agrupadas é uma variação do gráfico de barras simples que permite comparar múltiplas categorias dentro de cada grupo, colocando as barras lado a lado (agrupadas) para cada valor do eixo X.

# %% [markdown]
# ### Gráfico de barras empilhadas

# %%
categorias = ['A', 'B', 'C', 'D', 'E']
valores1 = [10, 15, 12, 8, 20]
valores2 = [5, 10, 8, 12, 7]
valores3 = [8, 5, 10, 7, 9]

plt.figure(figsize=(10, 6))

plt.bar(categorias, valores1, label='Produto 1', color='skyblue')
plt.bar(categorias, valores2, bottom=valores1, label='Produto 2',
color='lightgreen')
plt.bar(categorias, valores3, bottom=np.array(valores1) + np.array(valores2),
label='Produto 3', color='salmon')

plt.title('Gráfico de Barras Empilhadas', fontsize=16)
plt.xlabel('Categorias', fontsize=14)
plt.ylabel('Valores', fontsize=14)
plt.legend()
plt.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### O gráfico de barras empilhadas é usado para representar a composição de um total dentro de cada categoria, empilhando os valores de subgrupos dentro de uma única barra.

# %% [markdown]
# ###  Gráfico de Pizza

# %%
categorias = ['Categoria A', 'Categoria B', 'Categoria C', 'Categoria D',
'Outros']
valores = [35, 25, 20, 15, 5]
cores = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0']
explode = (0.1, 0, 0, 0, 0)

plt.figure(figsize=(10, 8))

plt.pie(valores, explode=explode, labels=categorias, colors=cores,
autopct='%1.1f%%',
shadow=True, startangle=90, textprops={'fontsize': 12})

plt.title('Distribuição por Categorias', fontsize=16)
plt.axis('equal')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### O gráfico de pizza é uma forma visual simples para mostrar a proporção ou participação percentual de diferentes categorias dentro de um todo.

# %% [markdown]
# ### Gráfico de Rosca (Donut)

# %%
categorias = ['Categoria A', 'Categoria B', 'Categoria C', 'Categoria D']
valores = [40, 30, 20, 10]
cores = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']

plt.figure(figsize=(10, 8))

plt.pie(valores, labels=categorias, colors=cores, autopct='%1.1f%%',
startangle=90, textprops={'fontsize': 12})

centro_circulo = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centro_circulo)

plt.text(0, 0, 'Total\n100%', horizontalalignment='center',
verticalalignment='center', fontsize=16)

plt.title('Gráfico de Rosca por Categorias', fontsize=16)
plt.axis('equal')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### O gráfico de rosca (donut) é uma variação do gráfico de pizza, com o centro “vazado”, formando um formato de anel. Assim como o gráfico de pizza, ele mostra a proporção de categorias dentro de um todo, onde cada segmento da rosca representa uma categoria proporcional ao seu valor.

# %% [markdown]
# ### Grid de Subplots

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

x = np.linspace(0, 10, 100)
axs[0, 0].plot(x, np.sin(x), 'r-')
axs[0, 0].set_title('Gráfico de Linha')
axs[0, 0].set_xlabel('x')
axs[0, 0].set_ylabel('sen(x)')
axs[0, 0].grid(True)

categorias = ['A', 'B', 'C', 'D']
valores = [15, 30, 25, 10]
axs[0, 1].bar(categorias, valores, color='skyblue')
axs[0, 1].set_title('Gráfico de Barras')
axs[0, 1].set_xlabel('Categorias')
axs[0, 1].set_ylabel('Valores')

np.random.seed(42)
x = np.random.rand(50)
y = x + 0.2*np.random.randn(50)
axs[1, 0].scatter(x, y, c=y, cmap='viridis')
axs[1, 0].set_title('Gráfico de Dispersão')
axs[1, 0].set_xlabel('x')
axs[1, 0].set_ylabel('y')

dados = np.random.normal(0, 1, 1000)
axs[1, 1].hist(dados, bins=20, color='lightgreen', edgecolor='black')
axs[1, 1].set_title('Histograma')
axs[1, 1].set_xlabel('Valores')
axs[1, 1].set_ylabel('Frequência')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### O grid de subplots é uma forma de organizar múltiplos gráficos em uma única figura, distribuindo-os em linhas e colunas, como uma grade (grid).

# %% [markdown]
# ### Subplots de Tamanhos Diferentes

# %%
fig = plt.figure(figsize=(12, 8))

ax1 = plt.subplot2grid((3, 3), (0, 0), colspan=2)
ax2 = plt.subplot2grid((3, 3), (0, 2), rowspan=2)
ax3 = plt.subplot2grid((3, 3), (1, 0))
ax4 = plt.subplot2grid((3, 3), (1, 1))
ax5 = plt.subplot2grid((3, 3), (2, 0), colspan=3)

x = np.linspace(0, 10, 100)
ax1.plot(x, np.sin(x), 'b-')
ax1.set_title('Gráfico de Linha')

categorias = ['A', 'B', 'C']
valores = [15, 30, 25]
ax2.barh(categorias, valores, color='salmon')
ax2.set_title('Barras Horizontais')

np.random.seed(42)
x = np.random.rand(20)
y = np.random.rand(20)
ax3.scatter(x, y, color='purple')
ax3.set_title('Scatter')

valores = [35, 25, 40]
ax4.pie(valores, autopct='%1.1f%%')
ax4.set_title('Pizza')

x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
ax5.fill_between(x, y1, y2, color='lightblue', alpha=0.5)
ax5.plot(x, y1, 'b-', x, y2, 'r-')
ax5.set_title('Gráfico de Área')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### O subplot de tamanhos diferentes é uma técnica para organizar múltiplos gráficos numa mesma figura, mas com cada gráfico tendo dimensões ou proporções distintas, ao contrário dos grids tradicionais que usam tamanhos iguais para todos os subplots.

# %% [markdown]
# ### Superficie 3D

# %%
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0,
antialiased=True)

ax.set_title('Superfície 3D', fontsize=16)
ax.set_xlabel('Eixo X', fontsize=12)
ax.set_ylabel('Eixo Y', fontsize=12)
ax.set_zlabel('Eixo Z', fontsize=12)
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### O gráfico de superfície 3D é uma visualização tridimensional que representa uma superfície contínua no espaço, exibindo a relação entre três variáveis geralmente duas variáveis independentes nos eixos X e Y, e uma variável dependente no eixo Z.

# %% [markdown]
# ### Gráfico de Dispersão 3D

# %%
np.random.seed(42)
n = 100
xs = np.random.rand(n)
ys = np.random.rand(n)
zs = np.random.rand(n)
colors = np.random.rand(n)
sizes = 50 * np.random.rand(n)

fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(xs, ys, zs, c=colors, s=sizes, alpha=0.6,
cmap='viridis')

ax.set_title('Gráfico de Dispersão 3D', fontsize=16)
ax.set_xlabel('Eixo X', fontsize=12)
ax.set_ylabel('Eixo Y', fontsize=12)
ax.set_zlabel('Eixo Z', fontsize=12)
fig.colorbar(scatter, shrink=0.5, aspect=5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### O gráfico de dispersão 3D é uma visualização que exibe pontos distribuídos em um espaço tridimensional, mostrando a relação entre três variáveis simultaneamente, normalmente nos eixos X, Y e Z. Cada ponto representa uma observação com valores para essas três dimensões, permitindo identificar padrões, agrupamentos, tendências, correlações ou outliers em dados multivariados.

# %% [markdown]
# ### Gráfico de Linhas 3D

# %%
theta = np.linspace(0, 8 * np.pi, 100)
z = np.linspace(0, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

ax.plot(x, y, z, 'b-', linewidth=2)

ax.set_title('Espiral 3D', fontsize=16)
ax.set_xlabel('Eixo X', fontsize=12)
ax.set_ylabel('Eixo Y', fontsize=12)
ax.set_zlabel('Eixo Z', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### O gráfico de linhas 3D plota uma ou várias linhas conectando pontos no espaço tridimensional, mostrando como uma variável evolui em função de outras duas. Ele é ideal para visualizar trajetórias, séries temporais ou funções paramétricas com três dimensões, permitindo observar padrões, tendências e relações complexas que não aparecem em gráficos 2D.

# %% [markdown]
# ### Estilos e temas

# %%
print("Estilos disponíveis:")
print(plt.style.available)

fig, axs = plt.subplots(2, 2, figsize=(15, 10))
estilos = ['default', 'seaborn-v0_8-darkgrid', 'ggplot', 'bmh']

x = np.linspace(0, 10, 100)
y = np.sin(x)

for ax, estilo in zip(axs.flat, estilos):
   with plt.style.context(estilo):
      ax.plot(x, y, 'r-', linewidth=2)
      ax.set_title(f'Estilo: {estilo}', fontsize=14)
      ax.set_xlabel('x')
      ax.set_ylabel('sen(x)')
      ax.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Estilos disponíveis:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ### Usar estilos é uma forma eficiente de aplicar temas visuais consistentes, profissionais e esteticamente agradáveis aos seus gráficos, sem precisar configurar manualmente cada detalhe. Essa técnica faz parte da personalização avançada de visualizações, que pode tornar suas análises mais claras e visualmente impactantes.

# %% [markdown]
# ### Personalização de Cores e Marcadores

# %%
plt.figure(figsize=(12, 8))

x = np.linspace(0, 10, 20)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.sin(x) * np.cos(x)
y4 = np.sin(x) * np.sin(x)

plt.plot(x, y1, 'ro-', linewidth=2, markersize=8, label='sen(x)')
plt.plot(x, y2, 'bs--', linewidth=2, markersize=8, label='cos(x)')
plt.plot(x, y3, 'g^-.', linewidth=2, markersize=8, label='sen(x)·cos(x)')
plt.plot(x, y4, 'yd:', linewidth=2, markersize=8, label='sen²(x)')

plt.title('Personalização de Cores e Marcadores', fontsize=16)
plt.xlabel('x', fontsize=14)
plt.ylabel('y', fontsize=14)
plt.grid(True)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()
print("Referência de Marcadores:")
print("'.' = ponto")
print("'o' = círculo")
print("'v' = triângulo para baixo")
print("'^' = triângulo para cima")
print("'s' = quadrado")
print("'*' = estrela")
print("'+' = mais")
print("'x' = x")
print("'D' = diamante")
print("\nReferência de Cores:")
print("'b' = azul (blue)")
print("'g' = verde (green)")
print("'r' = vermelho (red)")
print("'c' = ciano (cyan)")
print("'m' = magenta")
print("'y' = amarelo (yellow)")
print("'k' = preto (black)")
print("'w' = branco (white)")
print("\nReferência de Estilos de Linha:")
print("'-' = linha sólida")
print("'--' = linha tracejada")
print("'-.' = linha traço-ponto")
print("':' = linha pontilhada")
# Out:
# Referência de Marcadores:
# '.' = ponto
# 'o' = círculo
# 'v' = triângulo para baixo
# '^' = triângulo para cima
# 's' = quadrado
# '*' = estrela
# '+' = mais
# 'x' = x
# 'D' = diamante
#
# Referência de Cores:
# 'b' = azul (blue)
# 'g' = verde (green)
# 'r' = vermelho (red)
# 'c' = ciano (cyan)
# 'm' = magenta
# 'y' = amarelo (yellow)
# 'k' = preto (black)
# 'w' = branco (white)
#
# Referência de Estilos de Linha:
# '-' = linha sólida
# '--' = linha tracejada
# '-.' = linha traço-ponto
# ':' = linha pontilhada

# %% [markdown]
# ### A personalização de cores e marcadores no Matplotlib permite tornar os gráficos mais claros, informativos e visualmente atraentes, ajudando a destacar pontos importantes e facilitar a interpretação dos dados.

# %% [markdown]
# ### Dados de Séries Temporais

# %%
np.random.seed(42)
datas = pd.date_range(start='2023-01-01', periods=100, freq='D')
valores = np.cumsum(np.random.randn(100)) # Caminhada aleatória
df_serie = pd.DataFrame({'Data': datas, 'Valor': valores})

plt.figure(figsize=(12, 6))

plt.plot(df_serie['Data'], df_serie['Valor'], 'b-', linewidth=2)

plt.title('Série Temporal - Caminhada Aleatória', fontsize=16)
plt.xlabel('Data', fontsize=14)
plt.ylabel('Valor', fontsize=14)
plt.grid(True)

plt.gcf().autofmt_xdate()

z = np.polyfit(range(len(df_serie)), df_serie['Valor'], 1)
p = np.poly1d(z)
plt.plot(df_serie['Data'], p(range(len(df_serie))), "r--", linewidth=1.5,
label=f'Tendência: {z[0]:.4f}x + {z[1]:.4f}')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Dados de séries temporais são conjuntos de dados organizados em ordem cronológica, nos quais cada valor está associado a um instante ou período de tempo.

# %% [markdown]
# ### Mapa de Calor (Heatmap)

# %%
np.random.seed(42)
data = np.random.rand(10, 10)
correlacao = np.corrcoef(data)

plt.figure(figsize=(10, 8))

im = plt.imshow(correlacao, cmap='coolwarm')

plt.colorbar(im, label='Coeficiente de Correlação')

plt.title('Mapa de Calor - Matriz de Correlação', fontsize=16)
plt.xticks(np.arange(10), [f'Var {i+1}' for i in range(10)])
plt.yticks(np.arange(10), [f'Var {i+1}' for i in range(10)])

for i in range(10):
   for j in range(10):
      text = plt.text(j, i, f'{correlacao[i, j]:.2f}',
      ha="center", va="center", color="black" if
      correlacao[i, j] < 0.7 else "white")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### O mapa de calor (heatmap) é uma visualização gráfica onde os valores são representados por cores, permitindo identificar padrões, correlações e intensidades em uma matriz de dados.

# %% [markdown]
# ### Visualização com Seaborn

# %%
tips = sns.load_dataset('tips')

print("Primeiras linhas do dataset 'tips':")
print(tips.head())

plt.figure(figsize=(12, 10))

fig, axs = plt.subplots(2, 2, figsize=(15, 12))

sns.boxplot(x='day', y='total_bill', hue='sex', data=tips, ax=axs[0, 0])
axs[0, 0].set_title('Boxplot: Conta por Dia e Gênero', fontsize=14)

sns.violinplot(x='day', y='tip', hue='sex', data=tips, split=True, ax=axs[0,
1])
axs[0, 1].set_title('Violinplot: Gorjeta por Dia e Gênero', fontsize=14)

sns.regplot(x='total_bill', y='tip', data=tips, ax=axs[1, 0])
axs[1, 0].set_title('Regressão: Gorjeta vs Conta Total', fontsize=14)

sns.countplot(x='day', hue='time', data=tips, ax=axs[1, 1])
axs[1, 1].set_title('Contagem por Dia e Período', fontsize=14)

plt.tight_layout()
plt.show()
# Out:
# Primeiras linhas do dataset 'tips':
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Boxplot: Conta por Dia e Gênero
# Mostra a distribuição da conta total por dia da semana e gênero.
# Revela mediana, dispersão e outliers para cada grupo.
# Útil para comparar gastos entre homens e mulheres ao longo dos dias.
#
# Violinplot: Gorjeta por Dia e Gênero
# Combina boxplot com densidade para exibir a distribuição das gorjetas.
# Permite ver assimetria e variações entre os gêneros em cada dia.
# Ótimo para analisar formato e concentração dos dados.
#
# Regressão: Gorjeta vs Conta Total
# Mostra a relação entre o valor da conta e a gorjeta.
# A linha de regressão indica tendência linear entre as variáveis.
# É usado para avaliar se gorjetas aumentam com contas maiores.
#
# Contagem por Dia e Período
# Exibe a quantidade de atendimentos por dia da semana e horário.
# Permite identificar os dias mais movimentados e diferenças entre almoço e jantar.
# Ideal para análise de volume e padrões sazonais de atendimento.
