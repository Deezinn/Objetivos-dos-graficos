# %% [markdown]
# ### Import de libs / frameworks

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline

plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ### Gráfico de Linha

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, 'b-', linewidth=2, label='sen(x)')

plt.title('Função Seno', fontsize=16)
plt.xlabel('x', fontsize=14)
plt.ylabel('sen(x)', fontsize=14)
plt.grid(True)
plt.legend(fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### O gráfico de linha é usado para mostrar tendências ao longo do tempo. A dimensão está sempre no eixo x(horizontal) e as medidas no eixo y (vertical). Se o seu conjunto de dados deve ter pelo menos dois pontos de dados para desenhar uma linha. Um conjunto de dados com valor único é exibido como um ponto.

# %% [markdown]
# ### Múltiplas linhas

# %%
x = np.linspace(0, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.sin(x) * np.cos(x)

plt.figure(figsize=(12, 6))

plt.plot(x, y1, 'r-', linewidth=2, label='sen(x)')
plt.plot(x, y2, 'g-', linewidth=2, label='cos(x)')
plt.plot(x, y3, 'b--', linewidth=2, label='sen(x)·cos(x)')

plt.title('Funções Trigonométricas', fontsize=16)
plt.xlabel('x', fontsize=14)
plt.ylabel('y', fontsize=14)
plt.grid(True)
plt.legend(fontsize=12)
plt.axhline(y=0, color='k', linestyle='-', alpha=0.3)
plt.axvline(x=np.pi, color='k', linestyle='--', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Esse tipo de gráfico serve para comparar diversas séries de dados ao longo do tempo. Ao utilizar evoluções de diferentes ações no período.

# %% [markdown]
# ### Gráfico de dispersão ou Scatter

# %%
np.random.seed(42)
x = np.random.rand(50)
y = x + 0.3*np.random.randn(50)
cores = np.random.rand(50)
tamanhos = 1000 * np.random.rand(50)

plt.figure(figsize=(10, 6))

scatter = plt.scatter(x, y, c=cores, s=tamanhos, alpha=0.6, cmap='viridis')

plt.colorbar(scatter, label='Valor de Cor')
plt.title('Gráfico de Dispersão com Cores e Tamanhos Variáveis', fontsize=16)
plt.xlabel('Eixo X', fontsize=14)
plt.ylabel('Eixo Y', fontsize=14)
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### O gráfico de dispersão são utilizados para determinar a força de um relacionamento entre duas variaveis numéricas. O eixo-x representa a variável independente e o eixo-y  representa a variável dependente.
